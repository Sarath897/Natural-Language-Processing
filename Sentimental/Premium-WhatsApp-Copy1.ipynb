# %%
import pandas as pd

# %%
df = pd.read_csv("vini.txt",header=None,error_bad_lines=False,encoding='utf8')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 1040: expected 4 fields, saw 5\nSkipping line 5203: expected 4 fields, saw 8\nSkipping line 7419: expected 4 fields, saw 5\nSkipping line 7425: expected 4 fields, saw 7\nSkipping line 7462: expected 4 fields, saw 9\nSkipping line 7510: expected 4 fields, saw 5\nSkipping line 8002: expected 4 fields, saw 5\nSkipping line 8093: expected 4 fields, saw 5\nSkipping line 8264: expected 4 fields, saw 6\n'

# %%
df=df.drop(columns=[2, 3])
df
# Out:
#              0                                              1
# 1      3/11/22                       8:17 PM - Vini: Congrats
# 2      3/11/22             8:26 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Thanks
# 3      3/19/22                             9:45 PM - Vini: Hi
# 4      3/19/22                    9:45 PM - Vini: How are you
# 5      3/19/22            9:47 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Hm gud.
# ...        ...                                            ...
# 8069  12/22/25                   10:05 AM - Vini: How to open
# 8070  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>
# 8071  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>
# 8072  12/22/25                              10:52 AM - Vini:
# 8073  12/24/25                              10:39 AM - Vini:
#
# [8073 rows x 2 columns]

# %%
#fixing column name

df.columns=['Date','Chat']
df
# Out:
#           Date                                           Chat
# 1      3/11/22                       8:17 PM - Vini: Congrats
# 2      3/11/22             8:26 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Thanks
# 3      3/19/22                             9:45 PM - Vini: Hi
# 4      3/19/22                    9:45 PM - Vini: How are you
# 5      3/19/22            9:47 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Hm gud.
# ...        ...                                            ...
# 8069  12/22/25                   10:05 AM - Vini: How to open
# 8070  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>
# 8071  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>
# 8072  12/22/25                              10:52 AM - Vini:
# 8073  12/24/25                              10:39 AM - Vini:
#
# [8073 rows x 2 columns]

# %%
# spliting the time & msg

Message=df["Chat"].str.split("-",n=1,expand=True)
Message
# Out:
#                0                                   1
# 1       8:17 PM                       Vini: Congrats
# 2       8:26 PM             $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Thanks
# 3       9:45 PM                             Vini: Hi
# 4       9:45 PM                    Vini: How are you
# 5       9:47 PM            $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Hm gud.
# ...          ...                                 ...
# 8069   10:05 AM                    Vini: How to open
# 8070   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>
# 8071   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>
# 8072   10:52 AM                               Vini:
# 8073   10:39 AM                               Vini:
#
# [8073 rows x 2 columns]

# %%
df["Time"]=Message[0]
df
# Out:
#           Date                                           Chat        Time
# 1      3/11/22                       8:17 PM - Vini: Congrats    8:17 PM
# 2      3/11/22             8:26 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Thanks    8:26 PM
# 3      3/19/22                             9:45 PM - Vini: Hi    9:45 PM
# 4      3/19/22                    9:45 PM - Vini: How are you    9:45 PM
# 5      3/19/22            9:47 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Hm gud.    9:47 PM
# ...        ...                                            ...         ...
# 8069  12/22/25                   10:05 AM - Vini: How to open   10:05 AM
# 8070  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>   10:07 AM
# 8071  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>   10:07 AM
# 8072  12/22/25                              10:52 AM - Vini:    10:52 AM
# 8073  12/24/25                              10:39 AM - Vini:    10:39 AM
#
# [8073 rows x 3 columns]

# %%
# removing the time frm msg

Message1=Message[1].str.split(":",n=1,expand=True)
Message1
# Out:
#                       0                 1
# 1                  Vini          Congrats
# 2      $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄            Thanks
# 3                  Vini                Hi
# 4                  Vini       How are you
# 5      $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄           Hm gud.
# ...                 ...               ...
# 8069               Vini       How to open
# 8070   $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄   <Media omitted>
# 8071   $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄   <Media omitted>
# 8072               Vini
# 8073               Vini
#
# [8073 rows x 2 columns]

# %%
df["Name"]=Message1[0]
df
# Out:
#           Date                                           Chat        Time  \
# 1      3/11/22                       8:17 PM - Vini: Congrats    8:17 PM
# 2      3/11/22             8:26 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Thanks    8:26 PM
# 3      3/19/22                             9:45 PM - Vini: Hi    9:45 PM
# 4      3/19/22                    9:45 PM - Vini: How are you    9:45 PM
# 5      3/19/22            9:47 PM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: Hm gud.    9:47 PM
# ...        ...                                            ...         ...
# 8069  12/22/25                   10:05 AM - Vini: How to open   10:05 AM
# 8070  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>   10:07 AM
# 8071  12/22/25   10:07 AM - $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄: <Media omitted>   10:07 AM
# 8072  12/22/25                              10:52 AM - Vini:    10:52 AM
# 8073  12/24/25                              10:39 AM - Vini:    10:39 AM
#
#                    Name
# 1                  Vini
# 2      $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# 3                  Vini
# 4                  Vini
# 5      $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# ...                 ...
# 8069               Vini
# 8070   $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# 8071   $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# 8072               Vini
# 8073               Vini
#
# [8073 rows x 4 columns]

# %%
df["Chat"]=Message1[1]
df
# Out:
#           Date              Chat        Time               Name
# 1      3/11/22          Congrats    8:17 PM                Vini
# 2      3/11/22            Thanks    8:26 PM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# 3      3/19/22                Hi    9:45 PM                Vini
# 4      3/19/22       How are you    9:45 PM                Vini
# 5      3/19/22           Hm gud.    9:47 PM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# ...        ...               ...         ...                ...
# 8069  12/22/25       How to open   10:05 AM                Vini
# 8070  12/22/25   <Media omitted>   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# 8071  12/22/25   <Media omitted>   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄
# 8072  12/22/25                     10:52 AM                Vini
# 8073  12/24/25                     10:39 AM                Vini
#
# [8073 rows x 4 columns]

# %%
#rearrenginfg the columns 
df=df[["Date","Time","Name","Chat"]]
df
# Out:
#           Date        Time               Name              Chat
# 1      3/11/22    8:17 PM                Vini          Congrats
# 2      3/11/22    8:26 PM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄            Thanks
# 3      3/19/22    9:45 PM                Vini                Hi
# 4      3/19/22    9:45 PM                Vini       How are you
# 5      3/19/22    9:47 PM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄           Hm gud.
# ...        ...         ...                ...               ...
# 8069  12/22/25   10:05 AM                Vini       How to open
# 8070  12/22/25   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄   <Media omitted>
# 8071  12/22/25   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄   <Media omitted>
# 8072  12/22/25   10:52 AM                Vini
# 8073  12/24/25   10:39 AM                Vini
#
# [8073 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8073 entries, 1 to 8073
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8073 non-null   object
#  1   Time    7252 non-null   object
#  2   Name    7190 non-null   object
#  3   Chat    7182 non-null   object
# dtypes: object(4)
# memory usage: 315.4+ KB

# %%
#natural language tool kit

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.dropna(inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
## VADER is required for sentiment analysis.
## Without this lexicon, NLTK cannot calculate sentiment scores.


import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()

# %%
senti=sid.polarity_scores(dataset['Chat'][4])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_Senti
# Out:
#           Date        Time               Name              Chat  \
# 1      3/11/22    8:17 PM                Vini          Congrats
# 2      3/11/22    8:26 PM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄            Thanks
# 3      3/19/22    9:45 PM                Vini                Hi
# 4      3/19/22    9:45 PM                Vini       How are you
# 5      3/19/22    9:47 PM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄           Hm gud.
# ...        ...         ...                ...               ...
# 8069  12/22/25   10:05 AM                Vini       How to open
# 8070  12/22/25   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄   <Media omitted>
# 8071  12/22/25   10:07 AM    $@尺𝓐ʳŦꃅ Ҝꀎ爪₳Ɽ 🏄🏄   <Media omitted>
# 8072  12/22/25   10:52 AM                Vini
# 8073  12/24/25   10:39 AM                Vini
#
#                                                  scores  compound  Negtive  \
# 1     {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.5267      0.0
# 2     {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.4404      0.0
# 3     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 4     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 5     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# ...                                                 ...       ...      ...
# 8069  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 8070  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 8071  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 8072  {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 8073  {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...    0.0000      0.0
#
#       Postive  Neutral comp_score
# 1         1.0      0.0        pos
# 2         1.0      0.0        pos
# 3         0.0      1.0        pos
# 4         0.0      1.0        pos
# 5         0.0      1.0        pos
# ...       ...      ...        ...
# 8069      0.0      1.0        pos
# 8070      0.0      1.0        pos
# 8071      0.0      1.0        pos
# 8072      0.0      0.0        pos
# 8073      0.0      0.0        pos
#
# [7182 rows x 10 columns]

# %%
pos
# Out:
#      comp_score
# pos        6901
# neg         281

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)

# %%
for index,topic in enumerate(nmf_model.components_):
    results=([tfidf.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print(results)

# %%
topic_results=nmf_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)

# %%
df

# %%
df["Topic"].value_counts()

# %%
#!pip install wordCloud

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')

# %%
comment_words = []
stoplist = stopwords.words('english')
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
wordcloudss="This function saves image"
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    vv=" ".join(comment_words)          
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)         
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('wordcloud.PNG')
plt.show() 
print("Successfully created")
wordcloudss="This function saves image"
